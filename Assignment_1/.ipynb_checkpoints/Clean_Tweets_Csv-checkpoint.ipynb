# %%
import pandas as pd
import re

# %%
df = pd.read_csv("raw_tweets.csv")
df.shape
# Out:
# (5000, 4)

# %%
df
# Out:
#           screen_name                                               text  \
# 0              soompi  #Taecyeon To Join #2PM For Performance As Full...
# 1           joshrogin  Breaking: Vice President Pence will bring Fred...
# 2            SBNation  🥇3 days: Winter Olympics\n🏀55 days: Women's ...
# 3        BishopIkedi1  The Fantastic Four! Nigeria’s Bobsled &amp; Sk...
# 4           RoDCelaya  RT @nzaccardi: The Winter Olympics start this ...
# 5           AllOnFire  From the award-winning Snowman Paul book serie...
# 6            pamdon18  RT @Koreandogs: Boycott PyeongChang 2018 Winte...
# 7     phillippetrulak  RT @NFLRT: After winning Super Bowl MVP, Nick ...
# 8            pamdon18  RT @Koreandogs: [URGENT] Ask the PyeongChang 2...
# 9          corbangw14  RT @SBNation: 🥇3 days: Winter Olympics\n🏀55 ...
# 10         BrookingsK  RT @theblaze: Otto Warmbier’s father to join V...
# 11         nbc25fox66  In just three days the #Olympics begin in Pyeo...
# 12           powklan7  RT @newsmax: Vice President Pence will focus o...
# 13            BIANHTH  RT @minmeraki: [REPORTED BTS MIGHT DO A COLLAB...
# 14            ABabino  Winter Olympics Attack Expands with Top-Tier S...
# 15        EmetMihajlo  RT @HaraldDoornbos: Nice. Afghan stamp from 19...
# 16    rlstudentcounci  This Friday is Team Canada day as the 2018 Win...
# 17         iPRESIDIUM  Winter Olympics Attack Expands with Top-Tier S...
# 18         steadlight  RT @NYTStyles: Four Olympic athletes, includin...
# 19               ksbw  20 of the hottest athletes competing in the Wi...
# 20      myfitlifegear  The Workout That Saves Lindsey Vonn From Wipeo...
# 21         Sokkaa_RSS  Winter Olympics-Bound Bobsled Team Speak On Ni...
# 22           taeswfts  RT @minmeraki: [REPORTED BTS MIGHT DO A COLLAB...
# 23          jaybee230  RT @SBNation: 🥇3 days: Winter Olympics\n🏀55 ...
# 24     LaffsAtTheFash  RT @BlackFeminisms: Nigerian bobsled team to m...
# 25    Social_Media_c4  20 years later, a look back at the thrills and...
# 26        xtcollegebb  #collegehoops #ncaa 2018 Winter Olympics: IOC ...
# 27           jeonschu  RT @minmeraki: [REPORTED BTS MIGHT DO A COLLAB...
# 28    IndiaTodayNews1  Winter Olympics 2018: Linguistic barriers for ...
# 29    thedailyjournal  Vineland native to compete for Jamaica in Wint...
# ...               ...                                                ...
# 4970        Amy_Liz01  RT @minmeraki: [REPORTED BTS MIGHT DO A COLLAB...
# 4971      ncsulilwolf  RT @RalNightlife: S'mores special edition beer...
# 4972      playerpress  #NCAAF Wire: WATCH: Winter Olympic stars Linds...
# 4973       esaldivarb  How are analytics and big data playing a key r...
# 4974  Real_Infinity95  RT @TIME: What to know about the opening cerem...
# 4975   shine_for_vixx  RT @KoreanUpdates: #EXO #Baekhyun &amp; #VIXX ...
# 4976    zennichikuhon  Nathan Chen elevates U.S. hopes for figure ska...
# 4977  Real_Infinity95  RT @TIME: Here's a full breakdown of the dates...
# 4978        scottygfc  @davidfisher08 Is the Winter Olympics still on???
# 4990              Real_Infinity95           141
# 4991                  PlayerPress           550
# 4992                 IGN Vorstand           179
# 4993               ...david jones           395
# 4994               ...david jones           395
# 4995                 Northofseven            64
# 4996                Kavita Parmar           721
# 4997              Real_Infinity95           141
# 4998  가일 💫 inactive bc of school             1
# 4999           AnOnALLREDToDoRoJo           168
#
# [5000 rows x 4 columns]

# %%
columns = ['post_screen_name','text_screen_name', 'content']
clean_df =  pd.DataFrame(columns=columns)
clean_df
# Out:
# Empty DataFrame
# Columns: [post_screen_name, text_screen_name, content]
# Index: []

# %%
count = 0
for index, row in df.iterrows():
    ### Search for Mentions 
    name_lst = row['text'].split(" ")
    matching = [s for s in name_lst if "@" in s]
    if len(matching)>1:
        ### some things here
        for i in range(len(matching)):
            clean_df.loc[count+(i+1),'text_screen_name'] = matching[i]
            ### Add Screen Name
            clean_df.loc[count+(i+1),'post_screen_name'] = row['screen_name']
            ### Add Content Type
            if re.match("RT",row['text']):
                clean_df.loc[count+(i+1),'content'] = "RT"
            else:
                clean_df.loc[count+(i+1),'content'] = "Tweet"   
    elif len(matching)==0:
        clean_df.loc[count,'post_screen_name'] = row['screen_name']
        clean_df.loc[count,'text_screen_name'] = row['screen_name']
        clean_df.loc[count,'content'] = "Tweet"
    else: 
        clean_df.loc[count,'text_screen_name'] = matching[0]
        ### Add Screen Name
        clean_df.loc[count,'post_screen_name'] = row['screen_name']
        ### Add Content Type
        if re.match("RT",row['text']):
            clean_df.loc[count,'content'] = "RT"
        else:
            clean_df.loc[count,'content'] = "Tweet"
    len_df = len(clean_df)
    count += len_df

# %%
clean_df
# Out:
#          post_screen_name  text_screen_name content
# 0                  soompi            soompi   Tweet
# 1               joshrogin         joshrogin   Tweet
# 3                SBNation          SBNation   Tweet
# 6            BishopIkedi1      BishopIkedi1   Tweet
# 10              RoDCelaya       @nzaccardi:      RT
# 15              AllOnFire         AllOnFire   Tweet
# 21               pamdon18      @Koreandogs:      RT
# 28        phillippetrulak           @NFLRT:      RT
# 37               pamdon18      @Koreandogs:      RT
# 38               pamdon18           @Change      RT
# 46             corbangw14        @SBNation:      RT
# 57             BrookingsK        @theblaze:      RT
# 69             nbc25fox66        nbc25fox66   Tweet
# 82               powklan7         @newsmax:      RT
# 96                BIANHTH       @minmeraki:      RT
# 111               ABabino           ABabino   Tweet
# 127           EmetMihajlo  @HaraldDoornbos:      RT
# 144       rlstudentcounci   rlstudentcounci   Tweet
# 162            iPRESIDIUM        iPRESIDIUM   Tweet
# 182            steadlight       @NYTStyles:      RT
# 183            steadlight     @alexipappas,      RT
# 202                  ksbw              ksbw   Tweet
# 224         myfitlifegear     myfitlifegear   Tweet
# 247            Sokkaa_RSS        Sokkaa_RSS   Tweet
# 271              taeswfts       @minmeraki:      RT
# 296             jaybee230        @SBNation:      RT
# 322        LaffsAtTheFash  @BlackFeminisms:      RT
# 349       Social_Media_c4   Social_Media_c4   Tweet
# 377           xtcollegebb       xtcollegebb   Tweet
# 406              jeonschu       @minmeraki:      RT
# ...                   ...               ...     ...
# 13778872      ncsulilwolf   @JimmyVsRaleigh      RT
# 13778873      ncsulilwolf                @…      RT
# 13784482      playerpress       playerpress   Tweet
# 13790096       esaldivarb       @TeamCanada   Tweet
# 13795711  Real_Infinity95            @TIME:      RT
# 13801327   shine_for_vixx   @KoreanUpdates:      RT
# 13806944    zennichikuhon     zennichikuhon   Tweet
# 13812562  Real_Infinity95            @TIME:      RT
# 13818181        scottygfc    @davidfisher08   Tweet
# 13823801  Real_Infinity95            @TIME:      RT
# 13829422      judymorris3       judymorris3   Tweet
# 13835044      clousemouse       clousemouse   Tweet
# 13840667    SamuelDavis__        @thestate:      RT
# 13846291       YoungVelis         @Essence:      RT
# 13851916          CloverW           CloverW   Tweet
# 13857542    Real_RobRossi    @bruce_arthur:      RT
# 13863169         bdnews24          bdnews24   Tweet
# 13868797      playerpress       playerpress   Tweet
# 13874426      playerpress       playerpress   Tweet
# 13880056     IsraelInstNZ      IsraelInstNZ   Tweet
# 13885687  Real_Infinity95            @TIME:      RT
# 13891319      playerpress       playerpress   Tweet
# 13896952     IGN_Vorstand         @Nextgov:      RT
# 13902586            _dpaj        @euronews:   Tweet
# 13908221            _dpaj             _dpaj   Tweet
# 13913857      Northofsevn       Northofsevn   Tweet
# 13919494       parmarkavi        parmarkavi   Tweet
# 13925132  Real_Infinity95            @TIME:      RT
# 13930771   chanxiuyeolmin       @baobobaek:      RT
# 13936411   ALLREDToDoRoJo    ALLREDToDoRoJo   Tweet
#
# [5641 rows x 3 columns]

# %%
def remove_weird_char(string):
    import re
    words = string.split()
    refined = []
    for i in words:
        refined.append(re.sub("[^\w]+", " ", i))  
    sentence = ' '.join([word for word in refined])
    sentence = sentence.replace(" ", "")
    return(sentence)

# %%
clean_df["test"] = clean_df["text_screen_name"].apply(remove_weird_char)
clean_df = clean_df.reset_index()

# %%
clean_df.loc[clean_df["test"] == '','test'] = clean_df[clean_df["test"] == '']['post_screen_name'].values

# %%
clean_df
# Out:
#          index post_screen_name  text_screen_name content             test
# 0            0           soompi            soompi   Tweet           soompi
# 1            1        joshrogin         joshrogin   Tweet        joshrogin
# 2            3         SBNation          SBNation   Tweet         SBNation
# 3            6     BishopIkedi1      BishopIkedi1   Tweet     BishopIkedi1
# 4           10        RoDCelaya       @nzaccardi:      RT        nzaccardi
# 5           15        AllOnFire         AllOnFire   Tweet        AllOnFire
# 6           21         pamdon18      @Koreandogs:      RT       Koreandogs
# 7           28  phillippetrulak           @NFLRT:      RT            NFLRT
# 8           37         pamdon18      @Koreandogs:      RT       Koreandogs
# 9           38         pamdon18           @Change      RT           Change
# 10          46       corbangw14        @SBNation:      RT         SBNation
# 11          57       BrookingsK        @theblaze:      RT         theblaze
# 12          69       nbc25fox66        nbc25fox66   Tweet       nbc25fox66
# 13          82         powklan7         @newsmax:      RT          newsmax
# 14          96          BIANHTH       @minmeraki:      RT        minmeraki
# 15         111          ABabino           ABabino   Tweet          ABabino
# 16         127      EmetMihajlo  @HaraldDoornbos:      RT   HaraldDoornbos
# 17         144  rlstudentcounci   rlstudentcounci   Tweet  rlstudentcounci
# 18         162       iPRESIDIUM        iPRESIDIUM   Tweet       iPRESIDIUM
# 19         182       steadlight       @NYTStyles:      RT        NYTStyles
# 20         183       steadlight     @alexipappas,      RT      alexipappas
# 21         202             ksbw              ksbw   Tweet             ksbw
# 22         224    myfitlifegear     myfitlifegear   Tweet    myfitlifegear
# 23         247       Sokkaa_RSS        Sokkaa_RSS   Tweet       Sokkaa_RSS
# 24         271         taeswfts       @minmeraki:      RT        minmeraki
# 25         296        jaybee230        @SBNation:      RT         SBNation
# 26         322   LaffsAtTheFash  @BlackFeminisms:      RT   BlackFeminisms
# 27         349  Social_Media_c4   Social_Media_c4   Tweet  Social_Media_c4
# 28         377      xtcollegebb       xtcollegebb   Tweet      xtcollegebb
# 29         406         jeonschu       @minmeraki:      RT        minmeraki
# ...        ...              ...               ...     ...              ...
# 5611  13778872      ncsulilwolf   @JimmyVsRaleigh      RT   JimmyVsRaleigh
# 5612  13778873      ncsulilwolf                @…      RT      ncsulilwolf
# 5613  13784482      playerpress       playerpress   Tweet      playerpress
# 5614  13790096       esaldivarb       @TeamCanada   Tweet       TeamCanada
# 5615  13795711  Real_Infinity95            @TIME:      RT             TIME
# 5616  13801327   shine_for_vixx   @KoreanUpdates:      RT    KoreanUpdates
# 5617  13806944    zennichikuhon     zennichikuhon   Tweet    zennichikuhon
# 5618  13812562  Real_Infinity95            @TIME:      RT             TIME
# 5619  13818181        scottygfc    @davidfisher08   Tweet    davidfisher08
# 5620  13823801  Real_Infinity95            @TIME:      RT             TIME
# 5621  13829422      judymorris3       judymorris3   Tweet      judymorris3
# 5622  13835044      clousemouse       clousemouse   Tweet      clousemouse
# 5623  13840667    SamuelDavis__        @thestate:      RT         thestate
# 5624  13846291       YoungVelis         @Essence:      RT          Essence
# 5625  13851916          CloverW           CloverW   Tweet          CloverW
# 5626  13857542    Real_RobRossi    @bruce_arthur:      RT     bruce_arthur
# 5627  13863169         bdnews24          bdnews24   Tweet         bdnews24
# 5628  13868797      playerpress       playerpress   Tweet      playerpress
# 5629  13874426      playerpress       playerpress   Tweet      playerpress
# 5630  13880056     IsraelInstNZ      IsraelInstNZ   Tweet     IsraelInstNZ
# 5631  13885687  Real_Infinity95            @TIME:      RT             TIME
# 5632  13891319      playerpress       playerpress   Tweet      playerpress
# 5633  13896952     IGN_Vorstand         @Nextgov:      RT          Nextgov
# 5634  13902586            _dpaj        @euronews:   Tweet         euronews
# 5635  13908221            _dpaj             _dpaj   Tweet            _dpaj
# 5636  13913857      Northofsevn       Northofsevn   Tweet      Northofsevn
# 5637  13919494       parmarkavi        parmarkavi   Tweet       parmarkavi
# 5638  13925132  Real_Infinity95            @TIME:      RT             TIME
# 5639  13930771   chanxiuyeolmin       @baobobaek:      RT        baobobaek
# 5640  13936411   ALLREDToDoRoJo    ALLREDToDoRoJo   Tweet   ALLREDToDoRoJo
#
# [5641 rows x 5 columns]

# %%
clean_df.to_csv("clean_tweets_v2.csv",index=False)

# %%
clean_df.shape
# Out:
# (5641, 5)
