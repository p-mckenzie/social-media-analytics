# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import re
# %matplotlib inline

# %%
G = nx.DiGraph()

# %%
df = pd.read_csv("clean_tweets.csv")

# %%
retweets = {}
listed_count = {}

# %%
for row in df.iterrows():
#     li.append(re.sub("[@:.]", "", row[1][1]))
#     li.append(row[1][0])
    if row[1][3] == "RT":
        if row[1][4] in retweets.keys():
            retweets[row[1][4]] += 1
        else:
            retweets[row[1][4]] = 1
    if row[1][1] in listed_count.keys():
        listed_count[row[1][1]] += 1
    else:
        listed_count[row[1][1]] = 1
    G.add_edge(row[1][1], row[1][4])

# %%
nx.draw_networkx(G, with_labels = False)

# %% [markdown]
# As you can see above, there are only a few people in the middle that connect otherwise wildy disconnected people. However, these are <b><i> all </i></b> terminal connections. As you'll see in the dataframe shortly, this will cause the betweeness of everynode to be 0.

# %%
net_df = pd.DataFrame({"degree":G.degree(), "betweenness":nx.betweenness_centrality(G, normalized=False), \
                       "closeness":nx.closeness_centrality(G), "retweets":retweets, "listed_count":listed_count})

# %%
net_df["scaled_degree"] = net_df["degree"]/G.number_of_nodes()

# %%
net_df = net_df.fillna(0)

# %%
net_df
# Out:
#                  betweenness  closeness  degree  listed_count  retweets  \
# 2018Anthony              0.0   0.000000       1           0.0      32.0
# ABC                      0.0   0.000000       1           0.0       2.0
# AlexShibutani            0.0   0.000000       1           0.0      50.0
# AlphaBravoUSA            0.0   0.000000       1           0.0      30.0
# AndreHebron1             0.0   0.017143       4         150.0       0.0
# AndreaW28925929          0.0   0.005714       1          50.0       0.0
# AngrierWHStaff           0.0   0.000000       1           0.0       0.0
# AnitaHendrieka           0.0   0.000000       1           0.0      50.0
# Autos_Agent              0.0   0.000000       2          50.0       0.0
# BenMurphyTV              0.0   0.005714       1          50.0       0.0
# Best_Presents_           0.0   0.005714       1          50.0       0.0
# Blooming_HL              0.0   0.005714       1           2.0       0.0
# Bluesky_447              0.0   0.005714       1          50.0       0.0
# BorissDoza               0.0   0.005714       1          30.0       0.0
# Bose                     0.0   0.000000       1           0.0      50.0
# BritishArmy              0.0   0.000000       2           0.0     100.0
# CNET                     0.0   0.000000       1           0.0       0.0
# CTL_sport                0.0   0.000000       1           0.0       7.0
# CarlEva691               0.0   0.011429       4         150.0      50.0
# CatholicRegistr          0.0   0.000000       2          50.0       0.0
# ChadPergram              0.0   0.000000       7          50.0     212.0
# Channel7                 0.0   0.000000       1           0.0       0.0
# CompuSOLVE               0.0   0.005714       1          50.0       0.0
# DJTagainin2020           0.0   0.005714       1          50.0       0.0
# DOI_Tour                 0.0   0.000000       1           0.0      50.0
# DangeRussWilson          0.0   0.000000       1           0.0      50.0
# DavidNakamura            0.0   0.000000       5           0.0     169.0
# ...                        ...
# mrstserc              0.017045
# myitim1               0.005682
# myongaji              0.005682
# nirregev              0.005682
# nytimes               0.005682
# obregon_aj            0.005682
# panamworldnews        0.011364
# patton_amye           0.005682
# pitchblackcards       0.011364
# purplerenes           0.005682
# pyeongchang2018       0.011364
# regcoral              0.005682
# rojastorrijos         0.011364
# sarahloyd             0.011364
# sarahndipitydu        0.005682
# sarambsimon           0.005682
# seulgifood            0.034091
# sjhsje0610            0.005682
# slh2813               0.005682
# sunriseon7            0.005682
# surijaan              0.005682
# syqau                 0.011364
# taralipinski          0.011364
# tealtan               0.017045
# tecnolang             0.017045
# timgreene207          0.005682
# timmshady             0.011364
# usatodaysports        0.011364
# willripleyCNN         0.011364
# yennnaaaa913          0.005682
#
# [176 rows x 6 columns]

# %%
net_df["score"] = (net_df["listed_count"]-net_df["listed_count"].mean())/net_df["listed_count"].std() + \
(net_df["closeness"] - net_df["closeness"].mean())/net_df["closeness"].std() + \
(net_df["retweets"] - net_df["retweets"].mean())/net_df["retweets"].std() + \
(net_df["scaled_degree"] - net_df["scaled_degree"].mean())/net_df["scaled_degree"].std()

# %% [markdown]
# Below are our top 50 influencers

# %%
net_df["score"].sort_values(ascending = False)[:50]
# Out:
# TIME               14.312105
# lerma_pau           9.472568
# tecnolang           7.479057
# karasskarim         7.026451
# AndreHebron1        7.026451
# ChadPergram         6.762247
# athleticsEHS        6.637803
# CarlEva691          6.637803
# IntelGaming         6.265929
# fuwayuzupi          6.263612
# jkoufis9613         6.263612
# tealtan             6.263612
# eazeee2004          6.263612
# seulgifood          6.030162
# mrstserc            5.753125
# Olympics            5.423903
# LandBRPOAS          3.428848
# davidpj70clark      3.428848
# DavidNakamura       3.296983
# _TechNerdEnt_       3.054656
# jenpsht             3.054656
# Rude4eyez_          3.054656
# bartoplayer         3.054656
# bob_dammit          2.179536
# Timbaxter1          1.450564
# intradue            0.982730
# katemcloughlin4     0.964091
# BritishArmy        -0.153528
# diceypineapples    -0.153528
# __biaduarte        -0.154300
# DJTagainin2020     -0.154300
# ecobackpackers     -0.154300
# CompuSOLVE         -0.154300
# dlazar13           -0.154300
# Tawny2222          -0.154300
# S_T_A_G            -0.154300
# WhigsnTwigs        -0.154300
# Essexsteve78       -0.154300
# Stephen_Gash       -0.154300
# chimjimochi        -0.154300
# cutler18           -0.154300
# DrJillGildeaGPS    -0.154300
# cslatersr          -0.154300
# ayymackarena       -0.154300
# StolenSweeties     -0.154300
# conciergelive      -0.154300
# Best_Presents_     -0.154300
# ciudadanourbano    -0.154300
# Bluesky_447        -0.154300
# yennnaaaa913       -0.154300
# Name: score, dtype: float64
