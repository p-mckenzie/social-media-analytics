# %%
import pandas as pd

# %%
df = pd.read_csv("raw_tweets.csv")

# %%
len(df)
# Out:
# 1000

# %%
df
# Out:
#      Unnamed: 0      screen_name  \
# 0             0      IvankaTrump
# 1             1    willripleyCNN
# 2             2      Independent
# 3             3    GoAnimalNSave
# 4             4        BenKatt80
# 5             5       micolo_sky
# 6             6          scwiggs
# 7             7         Haysmart
# 8             8  applevalleyvets
# 9             9     GlasgowAlbum
# 10           10  actonstylegroup
# 11           11       openomroep
# 12           12     ClydeMoerlie
# 13           13      ACCCarlisle
# 14           14       Jaime_stag
# 15           15         ayukovon
# 16           16      baechuunnie
# 17           17     EAblockchain
# 18           18       ViralPearl
# 19           19    thomaspublius
# 20           20    Ford14Gabriel
# 21           21        HectorGK3
# 22           22        NewsRains
# 23           23       sunriseon7
# 24           24         4mycyrus
# 25           25   AOTranslations
# 26           26      cdmcmachine
# ...
